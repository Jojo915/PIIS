# %% [markdown]
# # Data Analysis Notebook
# This notebook loads data, cleans it, and trains a simple model.

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head()

# %% [markdown]
# ## Data Cleaning
# Remove missing values and prepare the dataset.

# %%
df = df.dropna()
df['price'] = df['price'].astype(float)
df.describe()

# %% [markdown]
# ## Model Training
# Train a simple regression model.

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
